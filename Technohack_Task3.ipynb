# %% [markdown]
# <a href="https://colab.research.google.com/github/anirudhawagh/Technohack_Task3/blob/main/Technohack_Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name** - Visualization Using Histogram

# %% [markdown]
# # **Problem Statement** - Create a Histogram or Bar chart to visualize the distribution of data in a dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Dataset
database ='/content/drive/MyDrive/Task3 dataset.csv'
df =pd.read_csv(database)

# %%
#First Look
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.shape
# Out:
# (150, 6)

# %%
#First 5rows of dataset
df. head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
print(df.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Check for missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
duplicate_count = df.duplicated().sum()

# Printing the count of duplicate rows
print("Number of Duplicate Rows:", duplicate_count)
# Out:
# Number of Duplicate Rows: 0

# %%
import matplotlib.pyplot as plt
plt.hist(df['SepalLengthCm'], bins=15, edgecolor='k')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Length')
plt.show()

# %%
plt.hist(df['SepalWidthCm'], bins=15, edgecolor='k')
plt.xlabel('Sepal Width (cm)')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Width')
plt.show()

# %%
plt.hist(df['PetalLengthCm'], bins=15, edgecolor='k')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Frequency')
plt.title('Distribution of Petal Length')
plt.show()

# %%
plt.hist(df['PetalWidthCm'], bins=15, edgecolor='k')
plt.xlabel('Petal Width (cm)')
plt.ylabel('Frequency')
plt.title('Distribution of Petal Width')
plt.show()

# %%
import seaborn as sns
sns.countplot(data=df, x='Species', palette='Set2')
plt.xlabel('Species')
plt.ylabel('Count')
plt.title('Distribution of Species')
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=df, x='Species', y='SepalLengthCm', palette='Set2')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.title('Sepal Length by Species')
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=df, x='Species', y='PetalLengthCm', palette='Set2')
plt.xlabel('Species')
plt.ylabel('Petal Length (cm)')
plt.title('Petal Length by Species')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a violin plot for Sepal Width by Species
plt.figure(figsize=(10, 6))
sns.violinplot(x='Species', y='SepalWidthCm', data=df, palette='Set2')
plt.xlabel('Species')
plt.ylabel('Sepal Width (cm)')
plt.title('Violin Plot of Sepal Width by Species')
plt.show()

# %% [markdown]
# **Conclusion**
#
# In this project, I analyzed the Iris dataset, revealing key insights about iris flower species. I found that the dataset includes three species: Setosa, Versicolor, and Virginica, each with distinct characteristics.
#
# Sepal and petal measurements allowed me to distinguish species.
# Sepal width showed variations within species.
# Visualizations, including histograms and dot bar charts, highlighted data distributions and patterns.
# This project demonstrates my ability to conduct data analysis and visualization to understand and characterize iris flowers, aiding in species classification and botanic research. Future work may involve more detailed analysis and machine learning modeling.
